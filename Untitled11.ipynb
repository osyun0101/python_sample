# %%
import cv2
import matplotlib.pyplot as plt

kanzi = cv2.imread("kanzi.jpg")
kanzi = cv2.cvtColor(kanzi, cv2.COLOR_BGR2GRAY)

im = cv2.GaussianBlur(kanzi,  (7,7),0)
im = cv2.threshold(im, 140, 255,cv2.THRESH_BINARY_INV)[1]


plt.imshow(im)
plt.show()
