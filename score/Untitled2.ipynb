# %%
import numpy as np
import pickle
import keras
from sklearn.model_selection import train_test_split


im_size = 25
in_size = im_size * im_size
out_size = 46
path = './png_file/katakana.pickle'

data = pickle.load(open(path, 'rb'))

x = []
y = []
for d in data:
    num, img = d
    x.append(img.reshape(-1).astype('float')/ 255)
    y.append(keras.utils.to_categorical(num, out_size))
x = np.array(x)
y = np.array(y)

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, train_size=0.8)

model = keras.models.Sequential()
Dense = keras.layers.Dense
model.add(Dense(512, activation='relu', input_shape=(in_size,)))
model.add(Dense(out_size, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
model.fit(x_train, y_train, batch_size=20,epochs=50, verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=1)
print('正解率＝', score[1], 'loss', score[0])
# Out:
# Epoch 1/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 2.2341 - accuracy: 0.4311 - val_loss: 1.3767 - val_accuracy: 0.6554
# Epoch 2/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 1.0277 - accuracy: 0.7327 - val_loss: 0.8631 - val_accuracy: 0.7734
# Epoch 3/50
# 2766/2766 [==============================] - 4s 2ms/step - loss: 0.6771 - accuracy: 0.8215 - val_loss: 0.7115 - val_accuracy: 0.8069
# Epoch 4/50
# 2766/2766 [==============================] - 3s 1ms/step - loss: 0.5225 - accuracy: 0.8611 - val_loss: 0.5601 - val_accuracy: 0.8526
# Epoch 5/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.4301 - accuracy: 0.8842 - val_loss: 0.5594 - val_accuracy: 0.8489
# Epoch 6/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.3664 - accuracy: 0.9006 - val_loss: 0.4709 - val_accuracy: 0.8726
# Epoch 7/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.3193 - accuracy: 0.9130 - val_loss: 0.5037 - val_accuracy: 0.8655
# Epoch 8/50
# 2766/2766 [==============================] - 5s 2ms/step - loss: 0.2828 - accuracy: 0.9223 - val_loss: 0.5016 - val_accuracy: 0.8641
# Epoch 9/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.2483 - accuracy: 0.9326 - val_loss: 0.4350 - val_accuracy: 0.8823
# Epoch 10/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.2204 - accuracy: 0.9388 - val_loss: 0.4446 - val_accuracy: 0.8823
# Epoch 11/50
# 2766/2766 [==============================] - 3s 1ms/step - loss: 0.2030 - accuracy: 0.9451 - val_loss: 0.4191 - val_accuracy: 0.8917
# Epoch 12/50
# 2766/2766 [==============================] - 3s 1ms/step - loss: 0.1837 - accuracy: 0.9491 - val_loss: 0.4676 - val_accuracy: 0.8829
# Epoch 13/50
# 2766/2766 [==============================] - 4s 2ms/step - loss: 0.1672 - accuracy: 0.9530 - val_loss: 0.4189 - val_accuracy: 0.8927
# Epoch 14/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1498 - accuracy: 0.9579 - val_loss: 0.4393 - val_accuracy: 0.8908
# Epoch 15/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1410 - accuracy: 0.9612 - val_loss: 0.4581 - val_accuracy: 0.8865
# Epoch 16/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1309 - accuracy: 0.9627 - val_loss: 0.5104 - val_accuracy: 0.8782
# Epoch 17/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1212 - accuracy: 0.9658 - val_loss: 0.4663 - val_accuracy: 0.8906
# Epoch 18/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1155 - accuracy: 0.9669 - val_loss: 0.4749 - val_accuracy: 0.8892
# Epoch 19/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1050 - accuracy: 0.9708 - val_loss: 0.4515 - val_accuracy: 0.8967
# Epoch 20/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.1010 - accuracy: 0.9708 - val_loss: 0.4850 - val_accuracy: 0.8872
# Epoch 21/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0931 - accuracy: 0.9724 - val_loss: 0.4838 - val_accuracy: 0.8980
# Epoch 22/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0950 - accuracy: 0.9719 - val_loss: 0.4765 - val_accuracy: 0.8975
# Epoch 23/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0848 - accuracy: 0.9750 - val_loss: 0.4439 - val_accuracy: 0.9058
# Epoch 24/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0839 - accuracy: 0.9754 - val_loss: 0.5467 - val_accuracy: 0.8869
# Epoch 25/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0773 - accuracy: 0.9769 - val_loss: 0.5309 - val_accuracy: 0.8935
# Epoch 26/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0763 - accuracy: 0.9771 - val_loss: 0.5493 - val_accuracy: 0.8883
# Epoch 27/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0736 - accuracy: 0.9784 - val_loss: 0.5627 - val_accuracy: 0.8873
# Epoch 28/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0718 - accuracy: 0.9786 - val_loss: 0.5326 - val_accuracy: 0.8996
# Epoch 29/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0673 - accuracy: 0.9798 - val_loss: 0.5327 - val_accuracy: 0.8966
# Epoch 30/50
# 2766/2766 [==============================] - 4s 1ms/step - loss: 0.0690 - accuracy: 0.9793 - val_loss: 0.5397 - val_accuracy: 0.8985
# Epoch 31/50
# 2740/2766 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9811
