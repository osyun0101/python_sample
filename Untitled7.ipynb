# %%
import cv2
import matplotlib.pyplot as plt

im = cv2.imread("flower.jpg")
im = cv2.resize(im, (300, 169))

img = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

img = cv2.GaussianBlur(img, (7,7), 0)
im2 = cv2.threshold(img, 140, 240, cv2.THRESH_BINARY_INV)[1]

plt.subplot(1,2,1)
plt.imshow(im2, cmap="gray")

frame = cv2.findContours(im2, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[1]

for fr in frame:
    x,y,w,h = cv2.boundingRect(fr)
    if w < 30 or w > 200: continue
    print(x,y,w,h)
    cv2.rectangle(im, (x,y),(x+w, y+h),(0, 255, 0), 2)

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
plt.savefig("flower_frame.png", dpi=300)
plt.show()
# Out:
# 97 64 30 28
# 101 9 90 81
