# %%
import keras 
from keras.datasets import mnist
from keras.optimizers import RMSprop
import matplotlib.pyplot as plot

in_size = 28 * 28
out_size = 10

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1, 784).astype('float32') / 255
X_test = X_test.reshape(-1, 784).astype('float32') / 255

y_train = keras.utils.to_categorical(y_train.astype('int32'),10)
y_test = keras.utils.to_categorical(y_test.astype('int32'),10)

Dense = keras.layers.Dense
Dropout = keras.layers.Dropout
model = keras.models.Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(),
    metrics=['accuracy']
)

hist = model.fit(X_train, y_train, epochs=50, batch_size=20, validation_data=(X_test, y_test))
score = model.evaluate(X_test, y_test, verbose=1)
print('正解率＝', score[1], 'loss', score[0])

plot.plot(hist.history['accuracy'])
plot.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.2332 - accuracy: 0.9338 - val_loss: 0.1332 - val_accuracy: 0.9679
# Epoch 2/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1682 - accuracy: 0.9635 - val_loss: 0.1444 - val_accuracy: 0.9697
# Epoch 3/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1683 - accuracy: 0.9682 - val_loss: 0.1468 - val_accuracy: 0.9727
# Epoch 4/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1693 - accuracy: 0.9700 - val_loss: 0.1714 - val_accuracy: 0.9768
# Epoch 5/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1681 - accuracy: 0.9721 - val_loss: 0.1859 - val_accuracy: 0.9741
# Epoch 6/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1725 - accuracy: 0.9740 - val_loss: 0.2190 - val_accuracy: 0.9723
# Epoch 7/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1698 - accuracy: 0.9749 - val_loss: 0.2145 - val_accuracy: 0.9754
# Epoch 8/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1611 - accuracy: 0.9760 - val_loss: 0.2101 - val_accuracy: 0.9778
# Epoch 9/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1571 - accuracy: 0.9779 - val_loss: 0.2361 - val_accuracy: 0.9784
# Epoch 10/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1644 - accuracy: 0.9781 - val_loss: 0.2582 - val_accuracy: 0.9754
# Epoch 11/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1701 - accuracy: 0.9777 - val_loss: 0.2463 - val_accuracy: 0.9771
# Epoch 12/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1611 - accuracy: 0.9785 - val_loss: 0.2916 - val_accuracy: 0.9774
# Epoch 13/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1765 - accuracy: 0.9786 - val_loss: 0.2697 - val_accuracy: 0.9761
# Epoch 14/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1704 - accuracy: 0.9798 - val_loss: 0.2990 - val_accuracy: 0.9782
# Epoch 15/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1695 - accuracy: 0.9795 - val_loss: 0.2988 - val_accuracy: 0.9788
# Epoch 16/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1617 - accuracy: 0.9817 - val_loss: 0.2969 - val_accuracy: 0.9814
# Epoch 17/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1610 - accuracy: 0.9814 - val_loss: 0.3417 - val_accuracy: 0.9774
# Epoch 18/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1711 - accuracy: 0.9818 - val_loss: 0.2883 - val_accuracy: 0.9750
# Epoch 19/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1624 - accuracy: 0.9818 - val_loss: 0.3161 - val_accuracy: 0.9783
# Epoch 20/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1607 - accuracy: 0.9827 - val_loss: 0.3551 - val_accuracy: 0.9798
# Epoch 21/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1689 - accuracy: 0.9818 - val_loss: 0.3938 - val_accuracy: 0.9792
# Epoch 22/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1596 - accuracy: 0.9830 - val_loss: 0.3755 - val_accuracy: 0.9791
# Epoch 23/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1570 - accuracy: 0.9839 - val_loss: 0.3984 - val_accuracy: 0.9763
# Epoch 24/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1687 - accuracy: 0.9837 - val_loss: 0.3664 - val_accuracy: 0.9797
# Epoch 25/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1676 - accuracy: 0.9828 - val_loss: 0.3455 - val_accuracy: 0.9797
# Epoch 26/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1741 - accuracy: 0.9834 - val_loss: 0.3456 - val_accuracy: 0.9798
# Epoch 27/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1704 - accuracy: 0.9840 - val_loss: 0.4348 - val_accuracy: 0.9801
# Epoch 28/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1668 - accuracy: 0.9836 - val_loss: 0.4926 - val_accuracy: 0.9770
# Epoch 29/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1800 - accuracy: 0.9842 - val_loss: 0.4679 - val_accuracy: 0.9770
# Epoch 30/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1587 - accuracy: 0.9845 - val_loss: 0.4663 - val_accuracy: 0.9800
# Epoch 31/50
# 3000/3000 [==============================] - 18s 6ms/step - loss: 0.1628 - accuracy: 0.9855 - val_loss: 0.4494 - val_accuracy: 0.9804
# Epoch 32/50
# 3000/3000 [==============================] - 18s 6ms/step - loss: 0.1666 - accuracy: 0.9850 - val_loss: 0.4258 - val_accuracy: 0.9802
# Epoch 33/50
# 3000/3000 [==============================] - 18s 6ms/step - loss: 0.1772 - accuracy: 0.9855 - val_loss: 0.4770 - val_accuracy: 0.9809
# Epoch 34/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1509 - accuracy: 0.9858 - val_loss: 0.4868 - val_accuracy: 0.9800
# Epoch 35/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1593 - accuracy: 0.9856 - val_loss: 0.4842 - val_accuracy: 0.9797
# Epoch 36/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1418 - accuracy: 0.9872 - val_loss: 0.6065 - val_accuracy: 0.9785
# Epoch 37/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1571 - accuracy: 0.9861 - val_loss: 0.4413 - val_accuracy: 0.9815
# Epoch 38/50
# 3000/3000 [==============================] - 19s 6ms/step - loss: 0.1619 - accuracy: 0.9878 - val_loss: 0.4822 - val_accuracy: 0.9792
# Epoch 39/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1488 - accuracy: 0.9869 - val_loss: 0.4550 - val_accuracy: 0.9812
# Epoch 40/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1462 - accuracy: 0.9874 - val_loss: 0.5887 - val_accuracy: 0.9813
# Epoch 41/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1560 - accuracy: 0.9869 - val_loss: 0.5254 - val_accuracy: 0.9794
# Epoch 42/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1336 - accuracy: 0.9879 - val_loss: 0.5176 - val_accuracy: 0.9814
# Epoch 43/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1602 - accuracy: 0.9878 - val_loss: 0.5918 - val_accuracy: 0.9800
# Epoch 44/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1637 - accuracy: 0.9873 - val_loss: 0.5435 - val_accuracy: 0.9823
# Epoch 45/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1483 - accuracy: 0.9884 - val_loss: 0.5320 - val_accuracy: 0.9787
# Epoch 46/50
# 3000/3000 [==============================] - 20s 7ms/step - loss: 0.1558 - accuracy: 0.9881 - val_loss: 0.4914 - val_accuracy: 0.9817
# Epoch 47/50
# 3000/3000 [==============================] - 22s 7ms/step - loss: 0.1468 - accuracy: 0.9876 - val_loss: 0.5949 - val_accuracy: 0.9826
# Epoch 48/50
# 1460/3000 [=============>................] - ETA: 10s - loss: 0.1343 - accuracy: 0.9890
